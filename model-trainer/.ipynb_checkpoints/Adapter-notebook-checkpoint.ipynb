# %%
import csv
from multiprocessing import Pool
from nupic.frameworks.opf.model_factory import ModelFactory
import datetime
import model_cpu
import model_mem
import model_disk
from multiprocessing import Process
from nupic.algorithms import anomaly_likelihood
import shutil
import os
import time
import requests
import subprocess
from subprocess import call

# %%
anomalyLikelihoodHelper = anomaly_likelihood.AnomalyLikelihood()

# %%
DATE_FORMAT = "%m/%d/%y %H:%M"
finalUtilityCpu=0.0 
SECONDS_PER_STEP= 15
adaptresult = {'metric': ' ', 'value':0, 'cost':0}
adaptoutcome = {'metric': ' ', 'value':0, 'cost':0, 'msg':''}
results=0
resultsA= []
prometheus='192.168.99.101'

# %%
 def run_cpu_adapter():
   model_cpu_model = ModelFactory.create(model_cpu.MODEL_PARAMS)
   model_cpu_model.enableInference({"predictedField": "cpu"})
   uc =0.0
   filename = 'cpu_adapt.csv'
   fileHandle1 = open(filename,"w")
   writer1 = csv.writer(fileHandle1)
   writer1.writerow(['timestamp', 'cpu', 'prediction', 'anomalyScore', 'anomalyLikelihood', 'sumOfUtilityFitness', 'sumOfUtilityFitnessPredicted', 'sumOfscore', 'sumOfWeaight', 'Uprev' , 'diffChange'] )

   sumOfUtilityFitness=0.0
   sumOfWeaight = 0.0 
   Uprev = 0
   Wprev = 0 
   diffChange=0 
   Ucpu=0
   Upredicted=0 
   sumOfscore=0
   sumOfUtilityFitnessPredicted=0
   utilityOfCpuPredicted=0
   for x in range(1,300):
      response = requests.get('http://admin:admin@'+prometheus+':9090/api/v1/query?query=sum(irate(node_cpu%7Bmode%3D%22idle%22%7D%5B30s%5D)%20*%20on(instance)%20group_left(node_name)%20node_meta%7Bnode_id%3D~%22.%2B%22%7D)%20*%20100%20%2F%20count(node_cpu%7Bmode%3D%22user%22%7D%20*%20on(instance)%20group_left(node_name)%20node_meta%7Bnode_id%3D~%22.%2B%22%7D)%20&start=1538182792&end=1538182852&step=30', timeout=5)
      #response = requests.get('http://admin:admin@prometheus:9090/api/v1/query?query=sum(irate(node_cpu%7Bmode%3D%22idle%22%7D%5B30s%5D)%20*%20on(instance)%20group_left(node_name)%20node_meta%7Bnode_id%3D~%22.%2B%22%7D)%20*%20100%20%2F%20count(node_cpu%7Bmode%3D%22user%22%7D%20*%20on(instance)%20group_left(node_name)%20node_meta%7Bnode_id%3D~%22.%2B%22%7D)%20&start=1538182792&end=1538182852&step=30', timeout=5)
      results = response.json()
      cpuData = results['data']['result'] 
      if len(cpuData) > 0:
        cpuValue = cpuData[0]['value']
        timestamp = datetime.datetime.fromtimestamp(float(cpuValue[0])).strftime('%m/%d/%y %H:%M')
         
      cpu = 100 - float(cpuValue[1])
      print 'time: ', timestamp, 'irate: ', x, ' cpu Usage: ',cpu 
      result = model_cpu_model.run({"cpu": cpu})
      prediction = result.inferences["multiStepBestPredictions"][1]
      anomalyScore = result.inferences['anomalyScore']
      anomalyLikelihood = anomalyLikelihoodHelper.anomalyProbability(cpu, anomalyScore, timestamp)

      #uc= (anomalyLikelihood * cpu + prediction * anomalyLikelihood )/(anomalyLikelihood + anomalyLikelihood) 
      #calculate equ 1 in paper 
      sumOfUtilityFitness=  (float(cpu) * float(anomalyLikelihood))
      sumOfUtilityFitnessPredicted=   (float(prediction) * float(anomalyLikelihood))
      sumOfWeaight =  float(anomalyLikelihood)
      sumOfscore =   float(anomalyScore)

      #calculate equ 3 in paper 
  

      #calculate equ 4 in paper 
      Ucurr = (float(cpu) * float(anomalyLikelihood))  
      diffChange = (Ucurr - Uprev)
      Uprev = Ucurr
      writer1.writerow([timestamp, cpu, prediction, anomalyScore, anomalyLikelihood, sumOfUtilityFitness, sumOfUtilityFitnessPredicted, sumOfscore, sumOfWeaight, Uprev , diffChange] )
      
      try:
        time.sleep(0)
      except:
        pass
   fileHandle1.close()
   print 'sumOfWeaight: ', sumOfWeaight, 'sumOfUtilityFitness: ', sumOfUtilityFitness, 'sumOfUtilityFitnessPredicted: ', sumOfUtilityFitnessPredicted, 'diffChange: ', diffChange 
   result_output = 'cpu_adapt.csv'
   utilityOfCpu=0.0
   sumChange = 0 
   with open(result_output, "rb") as result_input:
    csv_reader = csv.reader(result_input)
    csv_reader.next()
    for row in csv_reader:
      anomalyLikelihood = float(row[3])
      change = float(row[10])
      sumChange = sumChange + change 
      utilityOfCpu= utilityOfCpu + ((anomalyLikelihood * sumOfUtilityFitness)/sumOfWeaight)  
      utilityOfCpuPredicted= utilityOfCpuPredicted + ((anomalyLikelihood * sumOfUtilityFitnessPredicted)/sumOfWeaight)  

    print 'sumChange: ', sumChange
    cost=0 
    if sumChange > 0:
      cost = round((utilityOfCpu - utilityOfCpuPredicted) * (sumOfWeaight * sumOfscore)/(sumChange * 5.34),0)
    print 'utilityOfCpu: ', utilityOfCpu, 'cost: ', cost
    adaptresult['metric'] = 'utilityOfCpu'
    adaptresult['value'] = utilityOfCpu
    adaptresult['cost'] = cost
    resultsA.append(adaptresult.copy())

# %%
def get_cpu_observation():
    model_cpu_model = ModelFactory.create(model_cpu.MODEL_PARAMS)
    model_cpu_model.enableInference({"predictedField": "cpu"})
    response = requests.get('http://admin:admin@'+prometheus+':9090/api/v1/query?query=sum(irate(node_cpu%7Bmode%3D%22idle%22%7D%5B30s%5D)%20*%20on(instance)%20group_left(node_name)%20node_meta%7Bnode_id%3D~%22.%2B%22%7D)%20*%20100%20%2F%20count(node_cpu%7Bmode%3D%22user%22%7D%20*%20on(instance)%20group_left(node_name)%20node_meta%7Bnode_id%3D~%22.%2B%22%7D)%20&start=1538182792&end=1538182852&step=30', timeout=5)
    results = response.json()
    cpuData = results['data']['result'] 
    if len(cpuData) > 0:
        cpuValue = cpuData[0]['value']
        timestamp = datetime.datetime.fromtimestamp(float(cpuValue[0])).strftime('%m/%d/%y %H:%M') 
        cpu = 100 - float(cpuValue[1])
        #print 'time: ', timestamp, ' cpu Usage: ',cpu 
        result = model_cpu_model.run({"cpu": cpu})
        prediction = result.inferences["multiStepBestPredictions"][1]
        anomalyScore = result.inferences['anomalyScore']
        anomalyLikelihood = anomalyLikelihoodHelper.anomalyProbability(cpu, anomalyScore, timestamp)
    

    observations = np.array([cpu, prediction, anomalyScore, anomalyLikelihood])
    return observations

# %%
obs  = get_cpu_observation() 
print (obs)
# Out:
# [3.8 3.8 1.  0.5]

# %%
def basic_policy(obs): 
    angle = obs[1]
    return 0 if angle < 0 else 1

# %%
def step(action):
    if action == 1:
        x= 0
        x_dot = 0
        theta = 0
        theta_dot = 0 
     else:
        x= 0
        x_dot = 0
        theta = 0
        theta_dot = 0

# %%
totals = []
for episode in range(500):
    episode_rewards = 0
    obs = get_cpu_observation() 
    for step in range(100): # 1000 steps max, we don't want to run forever
        action = basic_policy(obs)
        obs, reward, done, info = env.step(action) 
        episode_rewards += reward
if done:
break
totals.append(episode_rewards)

# %% [markdown]
# # Use OpenAI

# %%
import gym
from policy_gradient import PolicyGradient
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
#env = gym.make('CartPole-v0')
#env = env.unwrapped

# %%
#Policy gradient has high variance, seed for reproducability
#env.seed(1)
# Out:
# [1L]

# %%
print("env.action_space", obs.action_space)
print("env.observation_space", env.observation_space)
print("env.observation_space.high", env.observation_space.high)
print("env.observation_space.low", env.observation_space.low)
# Out:
# ('env.action_space', Discrete(2))
# ('env.observation_space', Box(4,))
# ('env.observation_space.high', array([4.8000002e+00, 3.4028235e+38, 4.1887903e-01, 3.4028235e+38],
#       dtype=float32))
# ('env.observation_space.low', array([-4.8000002e+00, -3.4028235e+38, -4.1887903e-01, -3.4028235e+38],
#       dtype=float32))

# %%
RENDER_ENV = False
EPISODES = 500
rewards = []
RENDER_REWARD_MIN = 50

# %%
tf.reset_default_graph()

# %%
load_path = None #"output/weights/CartPole-v0.ckpt"
save_path = None #"output/weights/CartPole-v0-temp.ckpt"
PG = PolicyGradient(
        n_x = env.observation_space.shape[0],
        n_y = env.action_space.n,
        learning_rate=0.01,
        reward_decay=0.95,
        load_path=load_path,
        save_path=save_path
    )

# %%
obs = np.vectorize(get_cpu_observation)

# %%
out = obs()
# Out:
# time:  10/18/18 23:00  cpu Usage:  3.93333333333

# %%
#timestamp, cpu, prediction, anomalyScore, anomalyLikelihood = get_cpu_observation()
totals = []
for episode in range(500):
    episode_rewards = 0
    obs = 
for step in range(1000): # 1000 steps max, we don't want to run forever
action = basic_policy(obs)
obs, reward, done, info = env.step(action) episode_rewards += reward
if done:
break
totals.append(episode_rewards)

# %%
for episode in range(EPISODES):

        observation = env.reset()
        episode_reward = 0

        while True:
            if RENDER_ENV: env.render()

            # 1. Choose an action based on observation
            action = PG.choose_action(observation)

            # 2. Take action in the environment
            observation_, reward, done, info = env.step(action)

            # 3. Store transition for training
            PG.store_transition(observation, action, reward)

            if done:
                episode_rewards_sum = sum(PG.episode_rewards)
                rewards.append(episode_rewards_sum)
                max_reward_so_far = np.amax(rewards)

                print("==========================================")
                print("Episode: ", episode)
                print("Reward: ", episode_rewards_sum)
                print("Max reward so far: ", max_reward_so_far)

                # 4. Train neural network
                discounted_episode_rewards_norm = PG.learn()

                # Render env if we get to rewards minimum
                if max_reward_so_far > RENDER_REWARD_MIN: RENDER_ENV = False


                break

            # Save new observation
            observation = observation_
# Out:
# ==========================================
# ('Episode: ', 0)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 12.0)
# ==========================================
# ('Episode: ', 1)
# ('Reward: ', 16.0)
# ('Max reward so far: ', 16.0)
# ==========================================
# ('Episode: ', 2)
# ('Reward: ', 22.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 3)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 4)
# ('Reward: ', 15.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 5)
# ('Reward: ', 14.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 6)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 7)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 8)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 9)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 10)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 11)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 12)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 13)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 14)
# ('Reward: ', 15.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 15)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 16)
# ('Reward: ', 17.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 17)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 18)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 19)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 20)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 21)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 22)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 23)
# ('Reward: ', 15.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 24)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 25)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 26)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 27)
# ('Reward: ', 19.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 28)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 29)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 30)
# ('Reward: ', 21.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 31)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 32)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 33)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 34)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 35)
# ('Reward: ', 16.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 36)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 37)
# ('Reward: ', 19.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 38)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 39)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 40)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 41)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 42)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 43)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 44)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 45)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 46)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 47)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 48)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 49)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 50)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 51)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 52)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 53)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 54)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 55)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 56)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 57)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 58)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 59)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 60)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 61)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 62)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 63)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 64)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 65)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 66)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 67)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 68)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 69)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 70)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 71)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 72)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 73)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 74)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 75)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 76)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 77)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 78)
# ('Reward: ', 14.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 79)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 80)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 81)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 82)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 83)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 84)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 85)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 86)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 87)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 88)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 89)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 90)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 91)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 92)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 93)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 94)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 95)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 96)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 97)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 98)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 99)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 100)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 101)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 102)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 103)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 104)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 105)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 106)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 107)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 108)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 109)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 110)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 111)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 112)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 113)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 114)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 115)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 116)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 117)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 118)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 119)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 120)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 121)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 122)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 123)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 124)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 125)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 126)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 127)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 128)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 129)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 130)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 131)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 132)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 133)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 134)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 135)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 136)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 137)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 138)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 139)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 140)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 141)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 142)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 143)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 144)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 145)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 146)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 147)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 148)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 149)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 150)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 151)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 152)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 153)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 154)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 155)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 156)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 157)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 158)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 159)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 160)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 161)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 162)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 163)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 164)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 165)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 166)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 167)
# ('Reward: ', 15.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 168)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 169)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 170)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 171)
# ('Reward: ', 16.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 172)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 173)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 174)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 175)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 176)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 177)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 178)
# ('Reward: ', 14.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 179)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 180)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 181)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 182)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 183)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 184)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 185)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 186)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 187)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 188)
# ('Reward: ', 15.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 189)
# ('Reward: ', 17.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 190)
# ('Reward: ', 9.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 191)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 192)
# ('Reward: ', 17.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 193)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 194)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 195)
# ('Reward: ', 14.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 196)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 197)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 198)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 199)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 200)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 201)
# ('Reward: ', 15.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 202)
# ('Reward: ', 10.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 203)
# ('Reward: ', 17.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 204)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 205)
# ('Reward: ', 14.0)
# ('Max reward so far: ', 22.0)
# ==========================================
# ('Episode: ', 206)
# ('Reward: ', 28.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 207)
# ('Reward: ', 15.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 208)
# ('Reward: ', 8.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 209)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 210)
# ('Reward: ', 18.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 211)
# ('Reward: ', 17.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 212)
# ('Reward: ', 16.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 213)
# ('Reward: ', 21.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 214)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 215)
# ('Reward: ', 17.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 216)
# ('Reward: ', 12.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 217)
# ('Reward: ', 22.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 218)
# ('Reward: ', 18.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 219)
# ('Reward: ', 15.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 220)
# ('Reward: ', 16.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 221)
# ('Reward: ', 13.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 222)
# ('Reward: ', 17.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 223)
# ('Reward: ', 11.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 224)
# ('Reward: ', 18.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 225)
# ('Reward: ', 23.0)
# ('Max reward so far: ', 28.0)
# ==========================================
# ('Episode: ', 226)
# ('Reward: ', 34.0)
# ('Max reward so far: ', 34.0)
# ==========================================
# ('Episode: ', 227)
# ('Reward: ', 14.0)
# ('Max reward so far: ', 34.0)
# ==========================================
# ('Episode: ', 228)
# ('Reward: ', 46.0)
# ('Max reward so far: ', 46.0)
# ==========================================
# ('Episode: ', 229)
# ('Reward: ', 30.0)
# ('Max reward so far: ', 46.0)
# ==========================================
# ('Episode: ', 230)
# ('Reward: ', 42.0)
# ('Max reward so far: ', 46.0)
# ==========================================
# ('Episode: ', 231)
# ('Reward: ', 27.0)
# ('Max reward so far: ', 46.0)
# ==========================================
# ('Episode: ', 232)
# ('Reward: ', 47.0)
# ('Max reward so far: ', 47.0)
# ==========================================
# ('Episode: ', 233)
# ('Reward: ', 20.0)
# ('Max reward so far: ', 47.0)
# ==========================================
# ('Episode: ', 234)
# ('Reward: ', 69.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 235)
# ('Reward: ', 30.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 236)
# ('Reward: ', 19.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 237)
# ('Reward: ', 39.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 238)
# ('Reward: ', 33.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 239)
# ('Reward: ', 27.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 240)
# ('Reward: ', 19.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 241)
# ('Reward: ', 21.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 242)
# ('Reward: ', 44.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 243)
# ('Reward: ', 23.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 244)
# ('Reward: ', 50.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 245)
# ('Reward: ', 42.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 246)
# ('Reward: ', 33.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 247)
# ('Reward: ', 39.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 248)
# ('Reward: ', 57.0)
# ('Max reward so far: ', 69.0)
# ==========================================
# ('Episode: ', 249)
# ('Reward: ', 101.0)
# ('Max reward so far: ', 101.0)
# ==========================================
# ('Episode: ', 250)
# ('Reward: ', 64.0)
# ('Max reward so far: ', 101.0)
# ==========================================
# ('Episode: ', 251)
# ('Reward: ', 21.0)
# ('Max reward so far: ', 101.0)
# ==========================================
# ('Episode: ', 252)
# ('Reward: ', 82.0)
# ('Max reward so far: ', 101.0)
# ==========================================
# ('Episode: ', 253)
# ('Reward: ', 113.0)
# ('Max reward so far: ', 113.0)
# ==========================================
# ('Episode: ', 254)
# ('Reward: ', 77.0)
# ('Max reward so far: ', 113.0)
# ==========================================
# ('Episode: ', 255)
# ('Reward: ', 159.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 256)
# ('Reward: ', 58.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 257)
# ('Reward: ', 87.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 258)
# ('Reward: ', 75.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 259)
# ('Reward: ', 58.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 260)
# ('Reward: ', 71.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 261)
# ('Reward: ', 72.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 262)
# ('Reward: ', 100.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 263)
# ('Reward: ', 74.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 264)
# ('Reward: ', 50.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 265)
# ('Reward: ', 67.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 266)
# ('Reward: ', 102.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 267)
# ('Reward: ', 109.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 268)
# ('Reward: ', 97.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 269)
# ('Reward: ', 128.0)
# ('Max reward so far: ', 159.0)
# ==========================================
# ('Episode: ', 270)
# ('Reward: ', 178.0)
# ('Max reward so far: ', 178.0)
# ==========================================
# ('Episode: ', 271)
# ('Reward: ', 317.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 272)
# ('Reward: ', 68.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 273)
# ('Reward: ', 215.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 274)
# ('Reward: ', 81.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 275)
# ('Reward: ', 196.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 276)
# ('Reward: ', 79.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 277)
# ('Reward: ', 133.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 278)
# ('Reward: ', 180.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 279)
# ('Reward: ', 147.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 280)
# ('Reward: ', 144.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 281)
# ('Reward: ', 134.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 282)
# ('Reward: ', 111.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 283)
# ('Reward: ', 145.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 284)
# ('Reward: ', 102.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 285)
# ('Reward: ', 58.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 286)
# ('Reward: ', 24.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 287)
# ('Reward: ', 14.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 288)
# ('Reward: ', 102.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 289)
# ('Reward: ', 120.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 290)
# ('Reward: ', 115.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 291)
# ('Reward: ', 123.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 292)
# ('Reward: ', 109.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 293)
# ('Reward: ', 129.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 294)
# ('Reward: ', 130.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 295)
# ('Reward: ', 115.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 296)
# ('Reward: ', 106.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 297)
# ('Reward: ', 125.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 298)
# ('Reward: ', 106.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 299)
# ('Reward: ', 104.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 300)
# ('Reward: ', 111.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 301)
# ('Reward: ', 84.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 302)
# ('Reward: ', 116.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 303)
# ('Reward: ', 122.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 304)
# ('Reward: ', 142.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 305)
# ('Reward: ', 128.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 306)
# ('Reward: ', 134.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 307)
# ('Reward: ', 136.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 308)
# ('Reward: ', 199.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 309)
# ('Reward: ', 169.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 310)
# ('Reward: ', 177.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 311)
# ('Reward: ', 197.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 312)
# ('Reward: ', 262.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 313)
# ('Reward: ', 231.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 314)
# ('Reward: ', 299.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 315)
# ('Reward: ', 265.0)
# ('Max reward so far: ', 317.0)
# ==========================================
# ('Episode: ', 316)
# ('Reward: ', 347.0)
# ('Max reward so far: ', 347.0)
# ==========================================
# ('Episode: ', 317)
# ('Reward: ', 558.0)
# ('Max reward so far: ', 558.0)
# ==========================================
# ('Episode: ', 318)
# ('Reward: ', 458.0)
# ('Max reward so far: ', 558.0)
# ==========================================
# ('Episode: ', 319)
# ('Reward: ', 765.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 320)
# ('Reward: ', 393.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 321)
# ('Reward: ', 440.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 322)
# ('Reward: ', 377.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 323)
# ('Reward: ', 525.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 324)
# ('Reward: ', 294.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 325)
# ('Reward: ', 533.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 326)
# ('Reward: ', 413.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 327)
# ('Reward: ', 327.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 328)
# ('Reward: ', 316.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 329)
# ('Reward: ', 235.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 330)
# ('Reward: ', 485.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 331)
# ('Reward: ', 361.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 332)
# ('Reward: ', 317.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 333)
# ('Reward: ', 512.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 334)
# ('Reward: ', 501.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 335)
# ('Reward: ', 611.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 336)
# ('Reward: ', 764.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 337)
# ('Reward: ', 515.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 338)
# ('Reward: ', 483.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 339)
# ('Reward: ', 266.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 340)
# ('Reward: ', 373.0)
# ('Max reward so far: ', 765.0)
# ==========================================
# ('Episode: ', 341)
# ('Reward: ', 985.0)
# ('Max reward so far: ', 985.0)
# ==========================================
# ('Episode: ', 342)
# ('Reward: ', 2435.0)
# ('Max reward so far: ', 2435.0)
# ==========================================
# ('Episode: ', 343)
# ('Reward: ', 1179.0)
# ('Max reward so far: ', 2435.0)
# ==========================================
# ('Episode: ', 344)
# ('Reward: ', 8033.0)
# ('Max reward so far: ', 8033.0)
# ==========================================
# ('Episode: ', 345)
# ('Reward: ', 501.0)
# ('Max reward so far: ', 8033.0)
# ==========================================
# ('Episode: ', 346)
# ('Reward: ', 1344.0)
# ('Max reward so far: ', 8033.0)
# ==========================================
# ('Episode: ', 347)
# ('Reward: ', 3845.0)
# ('Max reward so far: ', 8033.0)
# ==========================================
# ('Episode: ', 348)
# ('Reward: ', 3058.0)
# ('Max reward so far: ', 8033.0)
# ==========================================
# ('Episode: ', 349)
# ('Reward: ', 2586.0)
# ('Max reward so far: ', 8033.0)
# ==========================================
# ('Episode: ', 350)
# ('Reward: ', 4551.0)
# ('Max reward so far: ', 8033.0)
# ==========================================
# ('Episode: ', 351)
# ('Reward: ', 12307.0)
# ('Max reward so far: ', 12307.0)
# ==========================================
# ('Episode: ', 352)
# ('Reward: ', 29030.0)
# ('Max reward so far: ', 29030.0)
# ==========================================
# ('Episode: ', 353)
# ('Reward: ', 20168.0)
# ('Max reward so far: ', 29030.0)
# ==========================================
# ('Episode: ', 354)
# ('Reward: ', 21069.0)
# ('Max reward so far: ', 29030.0)
# ==========================================
# ('Episode: ', 355)
# ('Reward: ', 72732.0)
# ('Max reward so far: ', 72732.0)
# ==========================================
# ('Episode: ', 356)
# ('Reward: ', 29417.0)
# ('Max reward so far: ', 72732.0)
# ==========================================
# ('Episode: ', 357)
# ('Reward: ', 2263.0)
# ('Max reward so far: ', 72732.0)
# ==========================================
# ('Episode: ', 358)
# ('Reward: ', 10066.0)
# ('Max reward so far: ', 72732.0)
# ==========================================
# ('Episode: ', 359)
# ('Reward: ', 34584.0)
# ('Max reward so far: ', 72732.0)
# ==========================================
# ('Episode: ', 360)
# ('Reward: ', 13021.0)
# ('Max reward so far: ', 72732.0)
# ==========================================
# ('Episode: ', 361)
# ('Reward: ', 2065.0)
# ('Max reward so far: ', 72732.0)
# ==========================================
# ('Episode: ', 362)
# ('Reward: ', 86844.0)
# ('Max reward so far: ', 86844.0)
# ==========================================
# ('Episode: ', 363)
# ('Reward: ', 18900.0)
# ('Max reward so far: ', 86844.0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-3e3dc8632084> in <module>()
#       8
#       9             # 1. Choose an action based on observation
# ---> 10             action = PG.choose_action(observation)
#      11
#      12             # 2. Take action in the environment
#
# /home/nupic/gc-swarm-global/model-trainer/policy_gradient.pyc in choose_action(self, observation)
#      86         # Select action using a biased sample
#      87         # this will return the index of the action we've sampled
# ---> 88         action = np.random.choice(range(len(prob_weights.ravel())), p=prob_weights.ravel())
#      89         return action
#      90
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# /usr/local/lib/python2.7/dist-packages/numpy/core/numerictypes.pyc in issubdtype(arg1, arg2)
#     711
#     712     """
# --> 713     if not issubclass_(arg1, generic):
#     714         arg1 = dtype(arg1).type
#     715     if not issubclass_(arg2, generic):
#
# /usr/local/lib/python2.7/dist-packages/numpy/core/numerictypes.pyc in issubclass_(arg1, arg2)
#     652     try:
#     653         return issubclass(arg1, arg2)
# --> 654     except TypeError:
#     655         return False
#     656
#
# KeyboardInterrupt:
